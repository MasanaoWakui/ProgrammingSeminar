# %% [markdown]
# # 第１回　データの読み込みと最短経路探索の改良

# %% [markdown]
# ## データ読み込みと整形

# %%
import os
import numpy as np
import networkx as nx
import csv
import time
import pandas as pd
import copy

# %% [markdown]
# ### まずはデータ読み込み
# **pandasを使ってみる**

# %%
path = '../datafile/SiouxFalls_node.tntp'
df = pd.read_csv(path, '\t', index_col=0)# 指定pathのファイルを，タブ区切りで，始めの列を見出しにして読む
df
# Out:
#               X          Y  ;
# Node
# 1    -96.770420  43.612828  ;
# 2    -96.711251  43.605813  ;
# 3    -96.774303  43.572962  ;
# 4    -96.747168  43.563654  ;
# 5    -96.731569  43.564034  ;
# 6    -96.711644  43.587586  ;
# 7    -96.693423  43.563844  ;
# 8    -96.711382  43.562324  ;
# 9    -96.731241  43.548596  ;
# 10   -96.731438  43.545271  ;
# 11   -96.746841  43.544131  ;
# 12   -96.780137  43.543941  ;
# 13   -96.793377  43.490707  ;
# 14   -96.751035  43.529306  ;
# 15   -96.731504  43.529401  ;
# 16   -96.711382  43.546744  ;
# 17   -96.711382  43.541280  ;
# 18   -96.694078  43.546744  ;
# 19   -96.711316  43.529591  ;
# 20   -96.711185  43.515333  ;
# 21   -96.730979  43.510485  ;
# 22   -96.731241  43.514858  ;
# 23   -96.750904  43.514858  ;
# 24   -96.749200  43.503164  ;

# %%
len(df)
# Out:
# 24

# %%
netfile = '../datafile/SiouxFalls_net.tntp'
net = pd.read_csv(netfile, skiprows=8, sep='\t')# 指定pathのファイルを，始めの8行を除いて，タブ区切りで読む

trimmed= [s.strip().lower() for s in net.columns]
net.columns = trimmed

# And drop the silly first andlast columns
net.drop(['~', ';'], axis=1, inplace=True)
net
# Out:
#     init_node  term_node      capacity  length  free_flow_time     b  power  \
# 0           1          2  25900.200640       6               6  0.15      4
# 1           1          3  23403.473190       4               4  0.15      4
# 2           2          1  25900.200640       6               6  0.15      4
# 3           2          6   4958.180928       5               5  0.15      4
# 4           3          1  23403.473190       4               4  0.15      4
# ..        ...        ...           ...     ...             ...   ...    ...
# 71         23         22   5000.000000       4               4  0.15      4
# 72         23         24   5078.508436       2               2  0.15      4
# 73         24         13   5091.256152       4               4  0.15      4
# 74         24         21   4885.357564       3               3  0.15      4
# 75         24         23   5078.508436       2               2  0.15      4
#
#     speed  toll  link_type
# 0       0     0          1
# 1       0     0          1
# 2       0     0          1
# 3       0     0          1
# 4       0     0          1
# ..    ...   ...        ...
# 71      0     0          1
# 72      0     0          1
# 73      0     0          1
# 74      0     0          1
# 75      0     0          1
#
# [76 rows x 10 columns]

# %%
len(net)
# Out:
# 76

# %%
net["capacity"][3]
# Out:
# 4958.180928

# %%
# ベクトルにも変換可能

tate = np.array(net["capacity"])
yoko = np.array(net[0:1])[0]

print("縦 =", tate)
print("横 =", yoko)
# Out:
# 縦 = [25900.20064  23403.47319  25900.20064   4958.180928 23403.47319
#  17110.52372  23403.47319  17110.52372  17782.7941    4908.82673
#  17782.7941    4947.995469 10000.        4958.180928  4947.995469
#   4898.587646  7841.81131  23403.47319   4898.587646  7841.81131
#   5050.193156  5045.822583 10000.        5050.193156 13915.78842
#  13915.78842  10000.       13512.00155   4854.917717  4993.510694
#   4908.82673  10000.        4908.82673   4876.508287 23403.47319
#   4908.82673  25900.20064  25900.20064   5091.256152  4876.508287
#   5127.526119  4924.790605 13512.00155   5127.526119 14564.75315
#   9599.180565  5045.822583  4854.917717  5229.910063 19679.89671
#   4993.510694  5229.910063  4823.950831 23403.47319  19679.89671
#  23403.47319  14564.75315   4823.950831  5002.607563 23403.47319
#   5002.607563  5059.91234   5075.697193  5059.91234   5229.910063
#   4885.357564  9599.180565  5075.697193  5229.910063  5000.
#   4924.790605  5000.        5078.508436  5091.256152  4885.357564
#   5078.508436]
# 横 = [1.00000000e+00 2.00000000e+00 2.59002006e+04 6.00000000e+00
#  6.00000000e+00 1.50000000e-01 4.00000000e+00 0.00000000e+00
#  0.00000000e+00 1.00000000e+00]

# %% [markdown]
# ### ネットワークのデータを必要なものだけ整形してみる

# %%
N = {}
L = {}

for i in range(len(net)):

    from_node = net["init_node"][i]
    to_node   = net["term_node"][i]
    ff_time   = net["free_flow_time"][i]
    
    L[i+1] = {}
    L[i+1]["index"]     = i
    L[i+1]["from_node"] = from_node
    L[i+1]["to_node"]   = to_node
    L[i+1]["ff_time"]   = ff_time
    
    if N.get(from_node):# Nの中に from_node があるなら
        N[from_node]['outlink_list'] = N[from_node]['outlink_list'] + [i+1]
    else:
        N[from_node] = {}
        N[from_node]["index"] = from_node-1
        N[from_node]['outlink_list'] = [i+1]
        N[from_node]['inlink_list']  = []
            
    if N.get(to_node):# Nの中に to_node があるなら
        N[to_node]['inlink_list'] = N[to_node]['inlink_list'] + [i+1]
    else:
        N[to_node] = {}
        N[to_node]["index"] = to_node-1
        N[to_node]['outlink_list'] = []
        N[to_node]['inlink_list']  = [i+1]

# %%
len(N)
# Out:
# 24

# %%
N
# Out:
# {1: {'index': 0, 'outlink_list': [1, 2], 'inlink_list': [3, 5]},
#  2: {'index': 1, 'outlink_list': [3, 4], 'inlink_list': [1, 14]},
#  3: {'index': 2, 'outlink_list': [5, 6, 7], 'inlink_list': [2, 8, 35]},
#  6: {'index': 5, 'outlink_list': [14, 15, 16], 'inlink_list': [4, 12, 19]},
#  4: {'index': 3, 'outlink_list': [8, 9, 10], 'inlink_list': [6, 11, 31]},
#  12: {'index': 11, 'outlink_list': [35, 36, 37], 'inlink_list': [7, 33, 38]},
#  5: {'index': 4, 'outlink_list': [11, 12, 13], 'inlink_list': [9, 15, 23]},
#  11: {'index': 10,
#   'outlink_list': [31, 32, 33, 34],
#   'inlink_list': [10, 27, 36, 40]},
#  9: {'index': 8, 'outlink_list': [23, 24, 25], 'inlink_list': [13, 21, 26]},
#  8: {'index': 7,
#   'outlink_list': [19, 20, 21, 22],
#   'inlink_list': [16, 17, 24, 47]},
#  7: {'index': 6, 'outlink_list': [17, 18], 'inlink_list': [20, 54]},
#  18: {'index': 17, 'outlink_list': [54, 55, 56], 'inlink_list': [18, 50, 60]},
#  16: {'index': 15,
#   'outlink_list': [47, 48, 49, 50],
#   'inlink_list': [22, 29, 52, 55]},
#  10: {'index': 9,
#   'outlink_list': [26, 27, 28, 29, 30],
#   'inlink_list': [25, 32, 43, 48, 51]},
#  15: {'index': 14,
#   'outlink_list': [43, 44, 45, 46],
#   'inlink_list': [28, 41, 57, 67]},
#  17: {'index': 16, 'outlink_list': [51, 52, 53], 'inlink_list': [30, 49, 58]},
#  14: {'index': 13, 'outlink_list': [40, 41, 42], 'inlink_list': [34, 44, 71]},
#  13: {'index': 12, 'outlink_list': [38, 39], 'inlink_list': [37, 74]},
#  24: {'index': 23, 'outlink_list': [74, 75, 76], 'inlink_list': [39, 66, 73]},
#  23: {'index': 22, 'outlink_list': [71, 72, 73], 'inlink_list': [42, 70, 76]},
#  19: {'index': 18, 'outlink_list': [57, 58, 59], 'inlink_list': [45, 53, 61]},
#  22: {'index': 21,
#   'outlink_list': [67, 68, 69, 70],
#   'inlink_list': [46, 63, 65, 72]},
#  20: {'index': 19,
#   'outlink_list': [60, 61, 62, 63],
#   'inlink_list': [56, 59, 64, 68]},
#  21: {'index': 20, 'outlink_list': [64, 65, 66], 'inlink_list': [62, 69, 75]}}

# %%
L
# Out:
# {1: {'index': 0, 'from_node': 1, 'to_node': 2, 'ff_time': 6},
#  2: {'index': 1, 'from_node': 1, 'to_node': 3, 'ff_time': 4},
#  3: {'index': 2, 'from_node': 2, 'to_node': 1, 'ff_time': 6},
#  4: {'index': 3, 'from_node': 2, 'to_node': 6, 'ff_time': 5},
#  5: {'index': 4, 'from_node': 3, 'to_node': 1, 'ff_time': 4},
#  6: {'index': 5, 'from_node': 3, 'to_node': 4, 'ff_time': 4},
#  7: {'index': 6, 'from_node': 3, 'to_node': 12, 'ff_time': 4},
#  8: {'index': 7, 'from_node': 4, 'to_node': 3, 'ff_time': 4},
#  9: {'index': 8, 'from_node': 4, 'to_node': 5, 'ff_time': 2},
#  10: {'index': 9, 'from_node': 4, 'to_node': 11, 'ff_time': 6},
#  11: {'index': 10, 'from_node': 5, 'to_node': 4, 'ff_time': 2},
#  12: {'index': 11, 'from_node': 5, 'to_node': 6, 'ff_time': 4},
#  13: {'index': 12, 'from_node': 5, 'to_node': 9, 'ff_time': 5},
#  14: {'index': 13, 'from_node': 6, 'to_node': 2, 'ff_time': 5},
#  15: {'index': 14, 'from_node': 6, 'to_node': 5, 'ff_time': 4},
#  16: {'index': 15, 'from_node': 6, 'to_node': 8, 'ff_time': 2},
#  17: {'index': 16, 'from_node': 7, 'to_node': 8, 'ff_time': 3},
#  18: {'index': 17, 'from_node': 7, 'to_node': 18, 'ff_time': 2},
#  19: {'index': 18, 'from_node': 8, 'to_node': 6, 'ff_time': 2},
#  20: {'index': 19, 'from_node': 8, 'to_node': 7, 'ff_time': 3},
#  21: {'index': 20, 'from_node': 8, 'to_node': 9, 'ff_time': 10},
#  22: {'index': 21, 'from_node': 8, 'to_node': 16, 'ff_time': 5},
#  23: {'index': 22, 'from_node': 9, 'to_node': 5, 'ff_time': 5},
#  24: {'index': 23, 'from_node': 9, 'to_node': 8, 'ff_time': 10},
#  25: {'index': 24, 'from_node': 9, 'to_node': 10, 'ff_time': 3},
#  26: {'index': 25, 'from_node': 10, 'to_node': 9, 'ff_time': 3},
#  27: {'index': 26, 'from_node': 10, 'to_node': 11, 'ff_time': 5},
#  28: {'index': 27, 'from_node': 10, 'to_node': 15, 'ff_time': 6},
#  29: {'index': 28, 'from_node': 10, 'to_node': 16, 'ff_time': 4},
#  30: {'index': 29, 'from_node': 10, 'to_node': 17, 'ff_time': 8},
#  31: {'index': 30, 'from_node': 11, 'to_node': 4, 'ff_time': 6},
#  32: {'index': 31, 'from_node': 11, 'to_node': 10, 'ff_time': 5},
#  33: {'index': 32, 'from_node': 11, 'to_node': 12, 'ff_time': 6},
#  34: {'index': 33, 'from_node': 11, 'to_node': 14, 'ff_time': 4},
#  35: {'index': 34, 'from_node': 12, 'to_node': 3, 'ff_time': 4},
#  36: {'index': 35, 'from_node': 12, 'to_node': 11, 'ff_time': 6},
#  37: {'index': 36, 'from_node': 12, 'to_node': 13, 'ff_time': 3},
#  38: {'index': 37, 'from_node': 13, 'to_node': 12, 'ff_time': 3},
#  39: {'index': 38, 'from_node': 13, 'to_node': 24, 'ff_time': 4},
#  40: {'index': 39, 'from_node': 14, 'to_node': 11, 'ff_time': 4},
#  41: {'index': 40, 'from_node': 14, 'to_node': 15, 'ff_time': 5},
#  42: {'index': 41, 'from_node': 14, 'to_node': 23, 'ff_time': 4},
#  43: {'index': 42, 'from_node': 15, 'to_node': 10, 'ff_time': 6},
#  44: {'index': 43, 'from_node': 15, 'to_node': 14, 'ff_time': 5},
#  45: {'index': 44, 'from_node': 15, 'to_node': 19, 'ff_time': 3},
#  46: {'index': 45, 'from_node': 15, 'to_node': 22, 'ff_time': 3},
#  47: {'index': 46, 'from_node': 16, 'to_node': 8, 'ff_time': 5},
#  48: {'index': 47, 'from_node': 16, 'to_node': 10, 'ff_time': 4},
#  49: {'index': 48, 'from_node': 16, 'to_node': 17, 'ff_time': 2},
#  50: {'index': 49, 'from_node': 16, 'to_node': 18, 'ff_time': 3},
#  51: {'index': 50, 'from_node': 17, 'to_node': 10, 'ff_time': 8},
#  52: {'index': 51, 'from_node': 17, 'to_node': 16, 'ff_time': 2},
#  53: {'index': 52, 'from_node': 17, 'to_node': 19, 'ff_time': 2},
#  54: {'index': 53, 'from_node': 18, 'to_node': 7, 'ff_time': 2},
#  55: {'index': 54, 'from_node': 18, 'to_node': 16, 'ff_time': 3},
#  56: {'index': 55, 'from_node': 18, 'to_node': 20, 'ff_time': 4},
#  57: {'index': 56, 'from_node': 19, 'to_node': 15, 'ff_time': 3},
#  58: {'index': 57, 'from_node': 19, 'to_node': 17, 'ff_time': 2},
#  59: {'index': 58, 'from_node': 19, 'to_node': 20, 'ff_time': 4},
#  60: {'index': 59, 'from_node': 20, 'to_node': 18, 'ff_time': 4},
#  61: {'index': 60, 'from_node': 20, 'to_node': 19, 'ff_time': 4},
#  62: {'index': 61, 'from_node': 20, 'to_node': 21, 'ff_time': 6},
#  63: {'index': 62, 'from_node': 20, 'to_node': 22, 'ff_time': 5},
#  64: {'index': 63, 'from_node': 21, 'to_node': 20, 'ff_time': 6},
#  65: {'index': 64, 'from_node': 21, 'to_node': 22, 'ff_time': 2},
#  66: {'index': 65, 'from_node': 21, 'to_node': 24, 'ff_time': 3},
#  67: {'index': 66, 'from_node': 22, 'to_node': 15, 'ff_time': 3},
#  68: {'index': 67, 'from_node': 22, 'to_node': 20, 'ff_time': 5},
#  69: {'index': 68, 'from_node': 22, 'to_node': 21, 'ff_time': 2},
#  70: {'index': 69, 'from_node': 22, 'to_node': 23, 'ff_time': 4},
#  71: {'index': 70, 'from_node': 23, 'to_node': 14, 'ff_time': 4},
#  72: {'index': 71, 'from_node': 23, 'to_node': 22, 'ff_time': 4},
#  73: {'index': 72, 'from_node': 23, 'to_node': 24, 'ff_time': 2},
#  74: {'index': 73, 'from_node': 24, 'to_node': 13, 'ff_time': 4},
#  75: {'index': 74, 'from_node': 24, 'to_node': 21, 'ff_time': 3},
#  76: {'index': 75, 'from_node': 24, 'to_node': 23, 'ff_time': 2}}

# %%
N[6]["outlink_list"]
# Out:
# [14, 15, 16]

# %% [markdown]
# ### 同じことは，pandasを使わなくてもできる
# **こっちのほうが記憶容量の節約になるかも．**

# %%
N = {}
L = {}

f = open("../datafile/SiouxFalls_net.tntp", "r")

flag = False
i = 0
for line in f:# ここでファイルを一行ずつ読んでいる．一気に読まないので使用メモリが少ない（多分）
    if flag == True:
        link_parameter = line.split()# 一つの文字列を，スペースとか改行とかタブとかで分割する
    
        from_node = int(link_parameter[0])
        to_node = int(link_parameter[1])
        ff_time = float(link_parameter[4])
        
        L[i+1] = {}
        L[i+1]["index"]     = i
        L[i+1]["from_node"] = from_node
        L[i+1]["to_node"]   = to_node
        L[i+1]["ff_time"]   = ff_time
        
        if N.get(from_node):# Nの中に from_node があるなら
            N[from_node]['outlink_list'] = N[from_node]['outlink_list'] + [i+1]
        else:
            N[from_node] = {}
            N[from_node]["index"] = from_node-1
            N[from_node]['outlink_list'] = [i+1]
            N[from_node]['inlink_list']  = []
            
        if N.get(to_node):# Nの中に to_node があるなら
            N[to_node]['inlink_list'] = N[to_node]['inlink_list'] + [i+1]
        else:
            N[to_node] = {}
            N[to_node]["index"] = to_node-1
            N[to_node]['outlink_list'] = []
            N[to_node]['inlink_list']  = [i+1]
            
        i = i + 1
    
    
    if line[0] == "~":
        flag = True
    
    
f.close()

# %%
L
# Out:
# {1: {'index': 0, 'from_node': 1, 'to_node': 2, 'ff_time': 6.0},
#  2: {'index': 1, 'from_node': 1, 'to_node': 3, 'ff_time': 4.0},
#  3: {'index': 2, 'from_node': 2, 'to_node': 1, 'ff_time': 6.0},
#  4: {'index': 3, 'from_node': 2, 'to_node': 6, 'ff_time': 5.0},
#  5: {'index': 4, 'from_node': 3, 'to_node': 1, 'ff_time': 4.0},
#  6: {'index': 5, 'from_node': 3, 'to_node': 4, 'ff_time': 4.0},
#  7: {'index': 6, 'from_node': 3, 'to_node': 12, 'ff_time': 4.0},
#  8: {'index': 7, 'from_node': 4, 'to_node': 3, 'ff_time': 4.0},
#  9: {'index': 8, 'from_node': 4, 'to_node': 5, 'ff_time': 2.0},
#  10: {'index': 9, 'from_node': 4, 'to_node': 11, 'ff_time': 6.0},
#  11: {'index': 10, 'from_node': 5, 'to_node': 4, 'ff_time': 2.0},
#  12: {'index': 11, 'from_node': 5, 'to_node': 6, 'ff_time': 4.0},
#  13: {'index': 12, 'from_node': 5, 'to_node': 9, 'ff_time': 5.0},
#  14: {'index': 13, 'from_node': 6, 'to_node': 2, 'ff_time': 5.0},
#  15: {'index': 14, 'from_node': 6, 'to_node': 5, 'ff_time': 4.0},
#  16: {'index': 15, 'from_node': 6, 'to_node': 8, 'ff_time': 2.0},
#  17: {'index': 16, 'from_node': 7, 'to_node': 8, 'ff_time': 3.0},
#  18: {'index': 17, 'from_node': 7, 'to_node': 18, 'ff_time': 2.0},
#  19: {'index': 18, 'from_node': 8, 'to_node': 6, 'ff_time': 2.0},
#  20: {'index': 19, 'from_node': 8, 'to_node': 7, 'ff_time': 3.0},
#  21: {'index': 20, 'from_node': 8, 'to_node': 9, 'ff_time': 10.0},
#  22: {'index': 21, 'from_node': 8, 'to_node': 16, 'ff_time': 5.0},
#  23: {'index': 22, 'from_node': 9, 'to_node': 5, 'ff_time': 5.0},
#  24: {'index': 23, 'from_node': 9, 'to_node': 8, 'ff_time': 10.0},
#  25: {'index': 24, 'from_node': 9, 'to_node': 10, 'ff_time': 3.0},
#  26: {'index': 25, 'from_node': 10, 'to_node': 9, 'ff_time': 3.0},
#  27: {'index': 26, 'from_node': 10, 'to_node': 11, 'ff_time': 5.0},
#  28: {'index': 27, 'from_node': 10, 'to_node': 15, 'ff_time': 6.0},
#  29: {'index': 28, 'from_node': 10, 'to_node': 16, 'ff_time': 4.0},
#  30: {'index': 29, 'from_node': 10, 'to_node': 17, 'ff_time': 8.0},
#  31: {'index': 30, 'from_node': 11, 'to_node': 4, 'ff_time': 6.0},
#  32: {'index': 31, 'from_node': 11, 'to_node': 10, 'ff_time': 5.0},
#  33: {'index': 32, 'from_node': 11, 'to_node': 12, 'ff_time': 6.0},
#  34: {'index': 33, 'from_node': 11, 'to_node': 14, 'ff_time': 4.0},
#  35: {'index': 34, 'from_node': 12, 'to_node': 3, 'ff_time': 4.0},
#  36: {'index': 35, 'from_node': 12, 'to_node': 11, 'ff_time': 6.0},
#  37: {'index': 36, 'from_node': 12, 'to_node': 13, 'ff_time': 3.0},
#  38: {'index': 37, 'from_node': 13, 'to_node': 12, 'ff_time': 3.0},
#  39: {'index': 38, 'from_node': 13, 'to_node': 24, 'ff_time': 4.0},
#  40: {'index': 39, 'from_node': 14, 'to_node': 11, 'ff_time': 4.0},
#  41: {'index': 40, 'from_node': 14, 'to_node': 15, 'ff_time': 5.0},
#  42: {'index': 41, 'from_node': 14, 'to_node': 23, 'ff_time': 4.0},
#  43: {'index': 42, 'from_node': 15, 'to_node': 10, 'ff_time': 6.0},
#  44: {'index': 43, 'from_node': 15, 'to_node': 14, 'ff_time': 5.0},
#  45: {'index': 44, 'from_node': 15, 'to_node': 19, 'ff_time': 3.0},
#  46: {'index': 45, 'from_node': 15, 'to_node': 22, 'ff_time': 3.0},
#  47: {'index': 46, 'from_node': 16, 'to_node': 8, 'ff_time': 5.0},
#  48: {'index': 47, 'from_node': 16, 'to_node': 10, 'ff_time': 4.0},
#  49: {'index': 48, 'from_node': 16, 'to_node': 17, 'ff_time': 2.0},
#  50: {'index': 49, 'from_node': 16, 'to_node': 18, 'ff_time': 3.0},
#  51: {'index': 50, 'from_node': 17, 'to_node': 10, 'ff_time': 8.0},
#  52: {'index': 51, 'from_node': 17, 'to_node': 16, 'ff_time': 2.0},
#  53: {'index': 52, 'from_node': 17, 'to_node': 19, 'ff_time': 2.0},
#  54: {'index': 53, 'from_node': 18, 'to_node': 7, 'ff_time': 2.0},
#  55: {'index': 54, 'from_node': 18, 'to_node': 16, 'ff_time': 3.0},
#  56: {'index': 55, 'from_node': 18, 'to_node': 20, 'ff_time': 4.0},
#  57: {'index': 56, 'from_node': 19, 'to_node': 15, 'ff_time': 3.0},
#  58: {'index': 57, 'from_node': 19, 'to_node': 17, 'ff_time': 2.0},
#  59: {'index': 58, 'from_node': 19, 'to_node': 20, 'ff_time': 4.0},
#  60: {'index': 59, 'from_node': 20, 'to_node': 18, 'ff_time': 4.0},
#  61: {'index': 60, 'from_node': 20, 'to_node': 19, 'ff_time': 4.0},
#  62: {'index': 61, 'from_node': 20, 'to_node': 21, 'ff_time': 6.0},
#  63: {'index': 62, 'from_node': 20, 'to_node': 22, 'ff_time': 5.0},
#  64: {'index': 63, 'from_node': 21, 'to_node': 20, 'ff_time': 6.0},
#  65: {'index': 64, 'from_node': 21, 'to_node': 22, 'ff_time': 2.0},
#  66: {'index': 65, 'from_node': 21, 'to_node': 24, 'ff_time': 3.0},
#  67: {'index': 66, 'from_node': 22, 'to_node': 15, 'ff_time': 3.0},
#  68: {'index': 67, 'from_node': 22, 'to_node': 20, 'ff_time': 5.0},
#  69: {'index': 68, 'from_node': 22, 'to_node': 21, 'ff_time': 2.0},
#  70: {'index': 69, 'from_node': 22, 'to_node': 23, 'ff_time': 4.0},
#  71: {'index': 70, 'from_node': 23, 'to_node': 14, 'ff_time': 4.0},
#  72: {'index': 71, 'from_node': 23, 'to_node': 22, 'ff_time': 4.0},
#  73: {'index': 72, 'from_node': 23, 'to_node': 24, 'ff_time': 2.0},
#  74: {'index': 73, 'from_node': 24, 'to_node': 13, 'ff_time': 4.0},
#  75: {'index': 74, 'from_node': 24, 'to_node': 21, 'ff_time': 3.0},
#  76: {'index': 75, 'from_node': 24, 'to_node': 23, 'ff_time': 2.0}}

# %%
N
# Out:
# {1: {'index': 0, 'outlink_list': [1, 2], 'inlink_list': [3, 5]},
#  2: {'index': 1, 'outlink_list': [3, 4], 'inlink_list': [1, 14]},
#  3: {'index': 2, 'outlink_list': [5, 6, 7], 'inlink_list': [2, 8, 35]},
#  6: {'index': 5, 'outlink_list': [14, 15, 16], 'inlink_list': [4, 12, 19]},
#  4: {'index': 3, 'outlink_list': [8, 9, 10], 'inlink_list': [6, 11, 31]},
#  12: {'index': 11, 'outlink_list': [35, 36, 37], 'inlink_list': [7, 33, 38]},
#  5: {'index': 4, 'outlink_list': [11, 12, 13], 'inlink_list': [9, 15, 23]},
#  11: {'index': 10,
#   'outlink_list': [31, 32, 33, 34],
#   'inlink_list': [10, 27, 36, 40]},
#  9: {'index': 8, 'outlink_list': [23, 24, 25], 'inlink_list': [13, 21, 26]},
#  8: {'index': 7,
#   'outlink_list': [19, 20, 21, 22],
#   'inlink_list': [16, 17, 24, 47]},
#  7: {'index': 6, 'outlink_list': [17, 18], 'inlink_list': [20, 54]},
#  18: {'index': 17, 'outlink_list': [54, 55, 56], 'inlink_list': [18, 50, 60]},
#  16: {'index': 15,
#   'outlink_list': [47, 48, 49, 50],
#   'inlink_list': [22, 29, 52, 55]},
#  10: {'index': 9,
#   'outlink_list': [26, 27, 28, 29, 30],
#   'inlink_list': [25, 32, 43, 48, 51]},
#  15: {'index': 14,
#   'outlink_list': [43, 44, 45, 46],
#   'inlink_list': [28, 41, 57, 67]},
#  17: {'index': 16, 'outlink_list': [51, 52, 53], 'inlink_list': [30, 49, 58]},
#  14: {'index': 13, 'outlink_list': [40, 41, 42], 'inlink_list': [34, 44, 71]},
#  13: {'index': 12, 'outlink_list': [38, 39], 'inlink_list': [37, 74]},
#  24: {'index': 23, 'outlink_list': [74, 75, 76], 'inlink_list': [39, 66, 73]},
#  23: {'index': 22, 'outlink_list': [71, 72, 73], 'inlink_list': [42, 70, 76]},
#  19: {'index': 18, 'outlink_list': [57, 58, 59], 'inlink_list': [45, 53, 61]},
#  22: {'index': 21,
#   'outlink_list': [67, 68, 69, 70],
#   'inlink_list': [46, 63, 65, 72]},
#  20: {'index': 19,
#   'outlink_list': [60, 61, 62, 63],
#   'inlink_list': [56, 59, 64, 68]},
#  21: {'index': 20, 'outlink_list': [64, 65, 66], 'inlink_list': [62, 69, 75]}}

# %% [markdown]
# # 課題：
# ## 1. Heap 構造を自分で作ってくる（class を作ってくると良い）．
#
# - 何らかの数値属性を持った要素（「所要時間ラベルを持ったノード」など）のリストをヒープに変換できること．
#
# - 変換してできたヒープに要素を追加，ヒープから最小要素を取得，という２操作ができること．
#
# 「ヒープとは？」については今日の説明に加えて，青本の pp.139 - 140 にも載っているので確認のこと．ググってもいろいろ出てくるはず．
#
# ## 2. 自作の Heap 構造を使ってダイクストラ法を作ってくる．
#
# - まず紹介したN, Lを使って，heapを使わないダイクストラ法（前回のやつ）を完成させる．
#
# - 次に，heapを使ってダイクストラ法を作る．
#
# - 最後に，前回と今回のダイクストラ法を大きい（1000リンクくらいの）ネットワークに適用して速さを確認する．
#
# ネットワークのデータは[ここ](https://github.com/bstabler/TransportationNetworks)から落としてくる．
